# %% [markdown]
# Setup SMPL Models
# Please register and download SMPL models here(https://smpl.is.tue.mpg.de/). Create folders under AvatarCLIP and put SMPL_NEUTRAL.pkl under the folder as follows.
# ## Setup SMPL Models
#
# Please register and download SMPL models here(https://smpl.is.tue.mpg.de/). Create folders under AvatarCLIP and put SMPL_NEUTRAL.pkl under the folder as follows. Rename the neutral model to SMPL_NEUTRAL.pkl
#
# ```
# ./AvatarCLIP/
# ├── ...
# └── smpl_models/
#     └── smpl/
#         └── SMPL_NEUTRAL.pkl
# ```

# %%
#!nvidia-smi
#!git clone https://github.com/hongfz16/AvatarCLIP.git
#!pip install torch torchvision torchaudio
#!pip install -r AvatarCLIP/requirements.txt
#!git clone https://github.com/hongfz16/neural_renderer.git
# Out:
# Cloning into 'neural_renderer'...
# remote: Enumerating objects: 1445, done.
# remote: Counting objects: 100% (1445/1445), done.
# remote: Compressing objects: 100% (492/492), done.
# remote: Total 1445 (delta 937), reused 1440 (delta 935), pack-reused 0
# Receiving objects: 100% (1445/1445), 26.21 MiB | 2.02 MiB/s, done.
# Resolving deltas: 100% (937/937), done.

# %%
# @title Setup the Environment: 2. Modify neural_renderer
#with open('neural_renderer/neural_renderer/perspective.py', 'r') as f:
#    lines = f.readlines()
#lines.insert(19, '    x[z<=0] = 0\n')
#lines.insert(20, '    y[z<=0] = 0\n')
#lines.insert(21, '    z[z<=0] = 0\n')
#with open('neural_renderer/neural_renderer/perspective.py', 'w') as f:
#    for l in lines:
#        f.write(l)

# %%
# %cd neural_renderer
# !python3 setup.py install
# %cd ..
# %cd AvatarGen/AppearanceGen
# Out:
# /home/gensyn/repos/AvatarCLIP/neural_renderer
# running install
# /home/gensyn/anaconda3/lib/python3.9/site-packages/setuptools/command/install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# /home/gensyn/anaconda3/lib/python3.9/site-packages/setuptools/command/easy_install.py:144: EasyInstallDeprecationWarning: easy_install command is deprecated. Use build and pip and other standards-based tools.
#   warnings.warn(
# running bdist_egg
# running egg_info
# creating neural_renderer_pytorch.egg-info
# writing neural_renderer_pytorch.egg-info/PKG-INFO
# writing dependency_links to neural_renderer_pytorch.egg-info/dependency_links.txt
# writing top-level names to neural_renderer_pytorch.egg-info/top_level.txt
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# reading manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# adding license file 'LICENSE'
# writing manifest file 'neural_renderer_pytorch.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.9
# creating build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/load_obj.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/lighting.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/save_obj.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/get_points_from_angles.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/vertices_to_faces.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/rasterize.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/look.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/__init__.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/projection.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/renderer.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/perspective.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/mesh.py -> build/lib.linux-x86_64-3.9/neural_renderer
# copying neural_renderer/look_at.py -> build/lib.linux-x86_64-3.9/neural_renderer
# creating build/lib.linux-x86_64-3.9/neural_renderer/cuda
# copying neural_renderer/cuda/__init__.py -> build/lib.linux-x86_64-3.9/neural_renderer/cuda
# running build_ext
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/utils/cpp_extension.py:820: UserWarning: There are no g++ version bounds defined for CUDA version 11.6
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'neural_renderer.cuda.load_textures' extension
# creating /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9
# creating /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer
# creating /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda
# Emitting ninja build file /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/load_textures_cuda.o.d -pthread -B /home/gensyn/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/gensyn/anaconda3/include -I/home/gensyn/anaconda3/include -fPIC -O2 -isystem /home/gensyn/anaconda3/include -fPIC -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/TH -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/THC -I/home/gensyn/anaconda3/include/python3.9 -c -c /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp -o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/load_textures_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp: In function ‘at::Tensor load_textures(at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, int)’:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:23: note: in expansion of macro ‘TORCH_CHECK’
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:17:24: note: in expansion of macro ‘CHECK_CUDA’
#    17 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:28:5: note: in expansion of macro ‘CHECK_INPUT’
#    28 |     CHECK_INPUT(image);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:23: note: in expansion of macro ‘TORCH_CHECK’
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:17:24: note: in expansion of macro ‘CHECK_CUDA’
#    17 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:29:5: note: in expansion of macro ‘CHECK_INPUT’
#    29 |     CHECK_INPUT(faces);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:23: note: in expansion of macro ‘TORCH_CHECK’
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:17:24: note: in expansion of macro ‘CHECK_CUDA’
#    17 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:30:5: note: in expansion of macro ‘CHECK_INPUT’
#    30 |     CHECK_INPUT(is_update);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:15:23: note: in expansion of macro ‘TORCH_CHECK’
#    15 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:17:24: note: in expansion of macro ‘CHECK_CUDA’
#    17 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:31:5: note: in expansion of macro ‘CHECK_INPUT’
#    31 |     CHECK_INPUT(textures);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# [2/2] /usr/bin/nvcc  -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/TH -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/THC -I/home/gensyn/anaconda3/include/python3.9 -c -c /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/load_textures_cuda_kernel.cu -o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/load_textures_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=load_textures -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 -std=c++14
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/SymInt.h(84): warning #68-D: integer conversion resulted in a change of sign
#
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/SymInt.h(84): warning #68-D: integer conversion resulted in a change of sign
#
# g++ -pthread -B /home/gensyn/anaconda3/compiler_compat -shared -Wl,-rpath,/home/gensyn/anaconda3/lib -Wl,-rpath-link,/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib -Wl,-rpath,/home/gensyn/anaconda3/lib -Wl,-rpath-link,/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/load_textures_cuda.o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/load_textures_cuda_kernel.o -L/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/lib -L/usr/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda_cu -ltorch_cuda_cpp -o build/lib.linux-x86_64-3.9/neural_renderer/cuda/load_textures.cpython-39-x86_64-linux-gnu.so
# building 'neural_renderer.cuda.rasterize' extension
# Emitting ninja build file /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/build.ninja...
# Compiling objects...
# Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# [1/2] c++ -MMD -MF /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/rasterize_cuda.o.d -pthread -B /home/gensyn/anaconda3/compiler_compat -Wno-unused-result -Wsign-compare -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /home/gensyn/anaconda3/include -I/home/gensyn/anaconda3/include -fPIC -O2 -isystem /home/gensyn/anaconda3/include -fPIC -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/TH -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/THC -I/home/gensyn/anaconda3/include/python3.9 -c -c /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp -o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/rasterize_cuda.o -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=rasterize -D_GLIBCXX_USE_CXX11_ABI=0 -std=c++14
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp: In function ‘std::vector<at::Tensor> forward_face_index_map(at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, at::Tensor, int, float, float, int, int, int)’:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:23: note: in expansion of macro ‘TORCH_CHECK’
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:68:24: note: in expansion of macro ‘CHECK_CUDA’
#    68 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:84:5: note: in expansion of macro ‘CHECK_INPUT’
#    84 |     CHECK_INPUT(faces);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:23: note: in expansion of macro ‘TORCH_CHECK’
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:68:24: note: in expansion of macro ‘CHECK_CUDA’
#    68 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:85:5: note: in expansion of macro ‘CHECK_INPUT’
#    85 |     CHECK_INPUT(face_index_map);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:23: note: in expansion of macro ‘TORCH_CHECK’
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:68:24: note: in expansion of macro ‘CHECK_CUDA’
#    68 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:86:5: note: in expansion of macro ‘CHECK_INPUT’
#    86 |     CHECK_INPUT(weight_map);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/rasterize_cuda.cpp:66:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    66 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
# ...
#    15 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:25:5: note: in expansion of macro ‘CHECK_INPUT’
#    25 |     CHECK_INPUT(textures);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/DeviceType.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Device.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/Allocator.h:6,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:7,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:13:42: warning: ‘at::DeprecatedTypeProperties& at::Tensor::type() const’ is deprecated: Tensor.type() is deprecated. Instead use Tensor.options(), which in many cases (e.g. in a constructor) is a drop-in replacement. If you were using data from type(), that is now available from Tensor itself, so instead of tensor.type().scalar_type(), use tensor.scalar_type() instead and instead of tensor.type().backend() use tensor.device(). [-Wdeprecated-declarations]
#    13 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                                          ^
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/macros/Macros.h:205:64: note: in definition of macro ‘C10_UNLIKELY’
#   205 | #define C10_UNLIKELY(expr) (__builtin_expect(static_cast<bool>(expr), 0))
#       |                                                                ^~~~
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/util/Exception.h:460:7: note: in expansion of macro ‘C10_UNLIKELY_OR_CONST’
#   460 |   if (C10_UNLIKELY_OR_CONST(!(cond))) {            \
#       |       ^~~~~~~~~~~~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:13:23: note: in expansion of macro ‘TORCH_CHECK’
#    13 | #define CHECK_CUDA(x) TORCH_CHECK(x.type().is_cuda(), #x " must be a CUDA tensor")
#       |                       ^~~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:15:24: note: in expansion of macro ‘CHECK_CUDA’
#    15 | #define CHECK_INPUT(x) CHECK_CUDA(x); CHECK_CONTIGUOUS(x)
#       |                        ^~~~~~~~~~
# /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:26:5: note: in expansion of macro ‘CHECK_INPUT’
#    26 |     CHECK_INPUT(image);
#       |     ^~~~~~~~~~~
# In file included from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/Tensor.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/DeviceGuard.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/ATen.h:11,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/types.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader_options.h:4,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/base.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader/stateful.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data/dataloader.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/data.h:3,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/all.h:8,
#                  from /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include/torch/torch.h:3,
#                  from /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda.cpp:1:
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/ATen/core/TensorBody.h:213:30: note: declared here
#   213 |   DeprecatedTypeProperties & type() const {
#       |                              ^~~~
# [2/2] /usr/bin/nvcc  -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/torch/csrc/api/include -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/TH -I/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/THC -I/home/gensyn/anaconda3/include/python3.9 -c -c /home/gensyn/repos/AvatarCLIP/neural_renderer/neural_renderer/cuda/create_texture_image_cuda_kernel.cu -o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/create_texture_image_cuda_kernel.o -D__CUDA_NO_HALF_OPERATORS__ -D__CUDA_NO_HALF_CONVERSIONS__ -D__CUDA_NO_BFLOAT16_CONVERSIONS__ -D__CUDA_NO_HALF2_OPERATORS__ --expt-relaxed-constexpr --compiler-options ''"'"'-fPIC'"'"'' -DTORCH_API_INCLUDE_EXTENSION_H '-DPYBIND11_COMPILER_TYPE="_gcc"' '-DPYBIND11_STDLIB="_libstdcpp"' '-DPYBIND11_BUILD_ABI="_cxxabi1011"' -DTORCH_EXTENSION_NAME=create_texture_image -D_GLIBCXX_USE_CXX11_ABI=0 -gencode=arch=compute_86,code=compute_86 -gencode=arch=compute_86,code=sm_86 -std=c++14
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/SymInt.h(84): warning #68-D: integer conversion resulted in a change of sign
#
# /home/gensyn/anaconda3/lib/python3.9/site-packages/torch/include/c10/core/SymInt.h(84): warning #68-D: integer conversion resulted in a change of sign
#
# g++ -pthread -B /home/gensyn/anaconda3/compiler_compat -shared -Wl,-rpath,/home/gensyn/anaconda3/lib -Wl,-rpath-link,/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib -Wl,-rpath,/home/gensyn/anaconda3/lib -Wl,-rpath-link,/home/gensyn/anaconda3/lib -L/home/gensyn/anaconda3/lib /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/create_texture_image_cuda.o /home/gensyn/repos/AvatarCLIP/neural_renderer/build/temp.linux-x86_64-3.9/neural_renderer/cuda/create_texture_image_cuda_kernel.o -L/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/lib -L/usr/lib64 -lc10 -ltorch -ltorch_cpu -ltorch_python -lcudart -lc10_cuda -ltorch_cuda_cu -ltorch_cuda_cpp -o build/lib.linux-x86_64-3.9/neural_renderer/cuda/create_texture_image.cpython-39-x86_64-linux-gnu.so
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/load_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/lighting.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/save_obj.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/get_points_from_angles.py -> build/bdist.linux-x86_64/egg/neural_renderer
# creating build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.9/neural_renderer/cuda/rasterize.cpython-39-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.9/neural_renderer/cuda/load_textures.cpython-39-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.9/neural_renderer/cuda/create_texture_image.cpython-39-x86_64-linux-gnu.so -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.9/neural_renderer/cuda/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer/cuda
# copying build/lib.linux-x86_64-3.9/neural_renderer/vertices_to_faces.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/rasterize.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/look.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/__init__.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/projection.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/renderer.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/perspective.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/mesh.py -> build/bdist.linux-x86_64/egg/neural_renderer
# copying build/lib.linux-x86_64-3.9/neural_renderer/look_at.py -> build/bdist.linux-x86_64/egg/neural_renderer
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/load_obj.py to load_obj.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/lighting.py to lighting.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/save_obj.py to save_obj.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/get_points_from_angles.py to get_points_from_angles.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/vertices_to_faces.py to vertices_to_faces.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/rasterize.py to rasterize.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look.py to look.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/__init__.py to __init__.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/projection.py to projection.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/renderer.py to renderer.cpython-39.pyc
# build/bdist.linux-x86_64/egg/neural_renderer/renderer.py:73: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif mode is 'rgb':
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/perspective.py to perspective.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/mesh.py to mesh.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/look_at.py to look_at.cpython-39.pyc
# creating stub loader for neural_renderer/cuda/load_textures.cpython-39-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/rasterize.cpython-39-x86_64-linux-gnu.so
# creating stub loader for neural_renderer/cuda/create_texture_image.cpython-39-x86_64-linux-gnu.so
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/load_textures.py to load_textures.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/rasterize.py to rasterize.cpython-39.pyc
# byte-compiling build/bdist.linux-x86_64/egg/neural_renderer/cuda/create_texture_image.py to create_texture_image.cpython-39.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying neural_renderer_pytorch.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# writing build/bdist.linux-x86_64/egg/EGG-INFO/native_libs.txt
# zip_safe flag not set; analyzing archive contents...
# neural_renderer.cuda.__pycache__.create_texture_image.cpython-39: module references __file__
# neural_renderer.cuda.__pycache__.load_textures.cpython-39: module references __file__
# neural_renderer.cuda.__pycache__.rasterize.cpython-39: module references __file__
# creating dist
# creating 'dist/neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg
# creating /home/gensyn/anaconda3/lib/python3.9/site-packages/neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg
# Extracting neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg to /home/gensyn/anaconda3/lib/python3.9/site-packages
# /home/gensyn/anaconda3/lib/python3.9/site-packages/neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg/neural_renderer/renderer.py:73: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   elif mode is 'rgb':
# Adding neural-renderer-pytorch 1.1.3 to easy-install.pth file
#
# Installed /home/gensyn/anaconda3/lib/python3.9/site-packages/neural_renderer_pytorch-1.1.3-py3.9-linux-x86_64.egg
# Processing dependencies for neural-renderer-pytorch==1.1.3
# Finished processing dependencies for neural-renderer-pytorch==1.1.3
# /home/gensyn/repos/AvatarCLIP
# /home/gensyn/repos/AvatarCLIP/AvatarGen/AppearanceGen

# %%
import os
import time
import logging
import argparse
import random
import numpy as np
import cv2 as cv
import trimesh
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.tensorboard import SummaryWriter
from shutil import copyfile
from icecream import ic
from tqdm import tqdm
from pyhocon import ConfigFactory
from models.dataset import Dataset
from models.dataset import SMPL_Dataset
from models.fields import RenderingNetwork, SDFNetwork, SingleVarianceNetwork, NeRF
from models.renderer import NeuSRenderer
from models.utils import lookat, random_eye, random_at, render_one_batch, batch_rodrigues
from models.utils import sphere_coord, random_eye_normal, rgb2hsv, differentiable_histogram
from models.utils import my_lbs, readOBJ
import clip
from smplx import build_layer
import imageio

to8b = lambda x : (255*np.clip(x,0,1)).astype(np.uint8)
from main import Runner

# %%
#@title Input Appearance Description (e.g. Iron Man)
AppearanceDescription = "Iron Man" #@param {type:"string"}

torch.set_default_tensor_type('torch.cuda.FloatTensor')
FORMAT = "[%(filename)s:%(lineno)s - %(funcName)20s() ] %(message)s"
logging.basicConfig(level=logging.INFO, format=FORMAT)
conf_path = 'confs/examples_small/example.conf'
f = open(conf_path)
conf_text = f.read()
f.close()
conf_text = conf_text.replace('{TOREPLACE}', AppearanceDescription)
# print(conf_text)
conf = ConfigFactory.parse_string(conf_text)
print("Prompt: {}".format(conf.get_string('clip.prompt')))
print("Face Prompt: {}".format(conf.get_string('clip.face_prompt')))
print("Back Prompt: {}".format(conf.get_string('clip.back_prompt')))
# Out:
# Prompt: a 3D rendering of a Iron Man in unreal engine
# Face Prompt: a 3D rendering of the face of Iron Man in unreal engine
# Back Prompt: a 3D rendering of the back of Iron Man in unreal engine

# %%
#@title Start the Generation!
runner = Runner(conf_path, 'train_clip', 'smpl', False, True, conf)
runner.init_clip()
runner.init_smpl()
runner.train_clip()
# Out:
# Load data: Begin
# [main.py:158 -             __init__() ] Load pretrain: ./pretrained_models/zero_beta_stand_pose_small.pth
# [main.py:619 -        load_pretrain() ] End
# Load data: End
# Use head height: 0.7
# Prompt: a 3D rendering of a Iron Man in unreal engine
# Face Prompt: a 3D rendering of the face of Iron Man in unreal engine
# Back Prompt: a 3D rendering of the back of Iron Man in unreal engine
# 2022-09-30 20:53:35.366264: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-30 20:53:35.885097: E tensorflow/stream_executor/cuda/cuda_blas.cc:2981] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2022-09-30 20:53:36.840824: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gensyn/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-09-30 20:53:36.840928: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/gensyn/anaconda3/lib/python3.9/site-packages/cv2/../../lib64:
# 2022-09-30 20:53:36.840935: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# [utils.py:147 -    _init_num_threads() ] Note: NumExpr detected 20 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# [utils.py:159 -    _init_num_threads() ] NumExpr defaulting to 8 threads.
#   0%|                                                                                                                                                             | 0/30000 [00:00<?, ?it/s]/home/gensyn/anaconda3/lib/python3.9/site-packages/torch/functional.py:478: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2894.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
#   0%|▍                                                                                                                                                 | 99/30000 [00:20<1:40:08,  4.98it/s]
# ./exp/smpl/example
# iter:100 loss = 1.6079655885696411 lr=9.900000000000001e-05
# Validate: iter: 100, camera: 58
#   1%|▉                                                                                                                                                | 199/30000 [00:43<1:37:48,  5.08it/s]
# ./exp/smpl/example
# iter:200 loss = 1.638249158859253 lr=0.000199
# Validate: iter: 200, camera: 58
#   1%|█▍                                                                                                                                               | 299/30000 [01:05<1:42:15,  4.84it/s]
# ./exp/smpl/example
# iter:300 loss = 1.658524990081787 lr=0.000299
# Validate: iter: 300, camera: 58
#   1%|█▉                                                                                                                                               | 399/30000 [01:28<1:38:43,  5.00it/s]
# ./exp/smpl/example
# iter:400 loss = 1.6320805549621582 lr=0.00039900000000000005
# Validate: iter: 400, camera: 58
#   2%|██▍                                                                                                                                              | 499/30000 [01:50<1:47:57,  4.55it/s]
# ./exp/smpl/example
# iter:500 loss = 1.5864002704620361 lr=0.000499
# Validate: iter: 500, camera: 58
# threshold: 0.0
# [main.py:919 -        validate_mesh() ] End
#   2%|██▉                                                                                                                                              | 599/30000 [02:20<1:35:20,  5.14it/s]
# ./exp/smpl/example
# iter:600 loss = 1.656969428062439 lr=0.0004999868005541672
# Validate: iter: 600, camera: 58
#   2%|███▍                                                                                                                                             | 699/30000 [02:42<1:35:35,  5.11it/s]
# ./exp/smpl/example
# iter:700 loss = 1.620192527770996 lr=0.0004999466690610096
# Validate: iter: 700, camera: 58
#   2%|███▍                                                                                                                                             | 723/30000 [02:49<1:39:08,  4.92it/s]

# %%
#@title Generate a Video of Optimization Process (RGB)

import os
from tqdm import tqdm
import numpy as np
from IPython import display
from PIL import Image
from base64 import b64encode

image_folder = 'exp/smpl/example/validations_extra_fine'
image_fname = os.listdir(image_folder)
image_fname = sorted(image_fname)
image_fname = [os.path.join(image_folder, f) for f in image_fname]

init_frame = 1
last_frame = len(image_fname)
min_fps = 10
max_fps = 60
total_frames = last_frame - init_frame

length = 15 #Desired time of the video in seconds

frames = []
for i in range(init_frame, last_frame): #
    frames.append(Image.open(image_fname[i]))

#fps = last_frame/10
fps = np.clip(total_frames/length,min_fps,max_fps)

from subprocess import Popen, PIPE
p = Popen(['ffmpeg', '-y', '-f', 'image2pipe', '-vcodec', 'png', '-r', str(fps), '-i', '-', '-vcodec', 'libx264', '-r', str(fps), '-pix_fmt', 'yuv420p', '-crf', '17', '-preset', 'veryslow', 'video.mp4'], stdin=PIPE)
for im in tqdm(frames):
    im.save(p.stdin, 'PNG')
p.stdin.close()
p.wait()
mp4 = open('video.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

display.HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
#@title Generate a Video of Optimization Process (Normal)

import os
from tqdm import tqdm
import numpy as np
from IPython import display
from PIL import Image
from base64 import b64encode

image_folder = 'exp/smpl/example/normals'
image_fname = os.listdir(image_folder)
image_fname = sorted(image_fname)
image_fname = [os.path.join(image_folder, f) for f in image_fname]

init_frame = 1
last_frame = len(image_fname)
min_fps = 10
max_fps = 60
total_frames = last_frame - init_frame

length = 15 #Desired time of the video in seconds

frames = []
for i in range(init_frame, last_frame): #
    frames.append(Image.open(image_fname[i]))

#fps = last_frame/10
fps = np.clip(total_frames/length,min_fps,max_fps)

from subprocess import Popen, PIPE
p = Popen(['ffmpeg', '-y', '-f', 'image2pipe', '-vcodec', 'png', '-r', str(fps), '-i', '-', '-vcodec', 'libx264', '-r', str(fps), '-pix_fmt', 'yuv420p', '-crf', '17', '-preset', 'veryslow', 'video_normal.mp4'], stdin=PIPE)
for im in tqdm(frames):
    im.save(p.stdin, 'PNG')
p.stdin.close()
p.wait()
mp4 = open('video_normal.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

display.HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
# AvatarCLIP/AvatarGen/AppearanceGen/exp/smpl/example/meshes/*.ply
